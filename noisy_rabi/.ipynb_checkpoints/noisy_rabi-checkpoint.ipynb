# %% [markdown]
# # Notebook Setup

# %%
import numpy as np
import h5py as h
import matplotlib.pyplot as plt
import matplotlib
from qutip import *

# %%
matplotlib.rcParams.update(
        {"font.family": "Georgia",
         "font.variant": "normal",
         "font.weight": "roman",
         "xtick.labelsize": 15,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.right": True,
         "ytick.direction": "in",
         "ytick.labelsize": 15,
#          "axes.prop_cycle": (matplotlib.cycler("color", ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])),
         "axes.labelsize": 15,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

# %%
cd data/2021-12-28
# Out:
# /Users/josephbroz/Desktop/lattice_notebooks/noisy_rabi/data/2021-12-28

# %%
data = {}
def set_data(name, files):
    if type(files) != list:
        files = [files]
    xdata = []
    ydata = []
    for file in files:
        s = "scan_data"
        d = h.File("SingleIonVAET/{}.h5".format(file), "r")[s]
        y, x = list(d.keys())
        xdata += list(d[x][()] * 1e6)
        ydata += list(d[y][()])
    data[name + "-x"] = xdata 
    data[name + "-y"] = ydata

# %% [markdown]
# # Background

# %% [markdown]
# The parametrized Hamiltonian we simulated:
#
# $\Large H = \frac{J}{2} \sigma_x + \frac{1}{2}[\Delta + \tilde{\Delta}(t)]\sigma_z$
#
# Measurement was performed of σ_z. Each data point represents the mean of 100 measurements.
#
# The values for Δ̃ correspond to the literal values that I input as s0 in the noise generation functions found here https://github.com/HaeffnerLab/lattice_notebooks/blob/master/noise_generation_example.ipynb.
#
# J was set to a value of 0.1, which sets the scale for the rest of the parameters. You can calculate the physical values of J by fitting the no-noise cases.

# %% [markdown]
# # No Noise

# %%
set_data("no_rotations", "1222_18")
set_data("no_noise_Δ0", "1229_39")
set_data("no_noise_ΔJ", "1233_05")

# %%
l1 = plt.plot(data["no_rotations-x"], data["no_rotations-y"], marker="o", label="no rotations")
l2 = plt.plot(data["no_noise_Δ0-x"], data["no_noise_Δ0-y"], marker="o", label="Δ=0")
l3 = plt.plot(data["no_noise_ΔJ-x"], data["no_noise_ΔJ-y"], marker="o", label="Δ=J")
l1[0].set_clip_on(False)
l2[0].set_clip_on(False)
l3[0].set_clip_on(False)
plt.xlabel("Time (μs)", fontsize=15)
plt.ylabel("Excited State Population")
plt.ylim(0, 1)
plt.legend(bbox_to_anchor=(1, 1), fontsize=15)
plt.show()

# %% [markdown]
# # White noise

# %%
# This data is just testing out the noise modulation setup. So we implement the setup but set the noise level to zero to check
# and see if the fidelity of the Rabi flops is affected (it seems that it is). A technical note here is that this setup
# requires a separate calibration of the rotated basis Rabi phase from the one without the noise setup.

# %%
set_data("white_noise_Δ0_Δ̃0", "1258_02")
set_data("white_noise_ΔJ_Δ̃0", "1305_08")

# %%
l1 = plt.plot(data["white_noise_Δ0_Δ̃0-x"], data["white_noise_Δ0_Δ̃0-y"], marker="o", label="Δ=0")
l2 = plt.plot(data["white_noise_ΔJ_Δ̃0-x"], data["white_noise_ΔJ_Δ̃0-y"], marker="o", label="Δ=J")
l1[0].set_clip_on(False)
l2[0].set_clip_on(False)
plt.xlabel("Time (μs)", fontsize=15)
plt.ylabel("Excited State Population")
plt.ylim(0, 1)
plt.legend(bbox_to_anchor=(1, 1), fontsize=15)

# %%
set_data("white_noise_Δ0_Δ̃02", "1310_44")
set_data("white_noise_Δ0_Δ̃04", ["1316_14", "1321_45"])

# %%
l1 = plt.plot(data["white_noise_Δ0_Δ̃02-x"], data["white_noise_Δ0_Δ̃02-y"], marker="o", label="Δ̃=0.2")
l2 = plt.plot(data["white_noise_Δ0_Δ̃04-x"], data["white_noise_Δ0_Δ̃04-y"], marker="o", label="Δ̃=0.4")
l1[0].set_clip_on(False)
l2[0].set_clip_on(False)
plt.xlabel("Time (μs)", fontsize=15)
plt.ylabel("Excited State Population")
plt.ylim(0, 1)
plt.legend(bbox_to_anchor=(1, 1), fontsize=15)
plt.title("White noise (Δ=0)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'White noise (Δ=0)')

# %%
set_data("white_noise_ΔJ_Δ̃02", "1324_09")
set_data("white_noise_ΔJ_Δ̃04", ["1329_13", "1332_39"])

# %%
l1 = plt.plot(data["white_noise_ΔJ_Δ̃02-x"], data["white_noise_ΔJ_Δ̃02-y"], marker="o", label="Δ̃=0.2")
l2 = plt.plot(data["white_noise_ΔJ_Δ̃04-x"], data["white_noise_ΔJ_Δ̃04-y"], marker="o", label="Δ̃=0.4")
l1[0].set_clip_on(False)
l2[0].set_clip_on(False)
plt.xlabel("Time (μs)", fontsize=15)
plt.ylabel("Excited State Population")
plt.ylim(0, 1)
plt.legend(bbox_to_anchor=(1, 1), fontsize=15)
plt.title("White noise (Δ=J)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'White noise (Δ=J)')

# %% [markdown]
# # Pink noise

# %%
set_data("pink_noise_Δ0_Δ̃02", ["1338_09", "1346_58"])
set_data("pink_noise_Δ0_Δ̃04", "1349_14")

# %%
l1 = plt.plot(data["pink_noise_Δ0_Δ̃02-x"], data["pink_noise_Δ0_Δ̃02-y"], marker="o", label="Δ̃=0.2")
l2 = plt.plot(data["pink_noise_Δ0_Δ̃04-x"], data["pink_noise_Δ0_Δ̃04-y"], marker="o", label="Δ̃=0.4")
l1[0].set_clip_on(False)
l2[0].set_clip_on(False)
plt.xlabel("Time (μs)", fontsize=15)
plt.ylabel("Excited State Population")
plt.ylim(0, 1)
plt.legend(bbox_to_anchor=(1, 1), fontsize=15)
plt.title("Pink noise (Δ=0)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pink noise (Δ=0)')

# %%
set_data("pink_noise_ΔJ_Δ̃02", "1358_57")
set_data("pink_noise_ΔJ_Δ̃04", "1354_42")

# %%
l1 = plt.plot(data["pink_noise_ΔJ_Δ̃02-x"], data["pink_noise_ΔJ_Δ̃02-y"], marker="o", label="Δ̃=0.2")
l2 = plt.plot(data["pink_noise_ΔJ_Δ̃04-x"], data["pink_noise_ΔJ_Δ̃04-y"], marker="o", label="Δ̃=0.4")
l1[0].set_clip_on(False)
l2[0].set_clip_on(False)
plt.xlabel("Time (μs)", fontsize=15)
plt.ylabel("Excited State Population")
plt.ylim(0, 1)
plt.legend(bbox_to_anchor=(1, 1), fontsize=15)
plt.title("Pink noise (Δ=J)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Pink noise (Δ=J)')

# %% [markdown]
# # Brown Noise

# %%
set_data("brown_noise_Δ0_Δ̃02", "1418_52")
set_data("brown_noise_Δ0_Δ̃04", "1414_37")

# %%
l1 = plt.plot(data["brown_noise_Δ0_Δ̃02-x"], data["brown_noise_Δ0_Δ̃02-y"], marker="o", label="Δ̃=0.2")
l2 = plt.plot(data["brown_noise_Δ0_Δ̃04-x"], data["brown_noise_Δ0_Δ̃04-y"], marker="o", label="Δ̃=0.4")
l1[0].set_clip_on(False)
l2[0].set_clip_on(False)
plt.xlabel("Time (μs)", fontsize=15)
plt.ylabel("Excited State Population")
plt.ylim(0, 1)
plt.legend(bbox_to_anchor=(1, 1), fontsize=15)
plt.title("Brown noise (Δ=0)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Brown noise (Δ=0)')

# %%
set_data("brown_noise_ΔJ_Δ̃02", "1404_25")
set_data("brown_noise_ΔJ_Δ̃04", "1408_41")

# %%
l1 = plt.plot(data["brown_noise_ΔJ_Δ̃02-x"], data["brown_noise_ΔJ_Δ̃02-y"], marker="o", label="Δ̃=0.2")
l2 = plt.plot(data["brown_noise_ΔJ_Δ̃04-x"], data["brown_noise_ΔJ_Δ̃04-y"], marker="o", label="Δ̃=0.4")
l1[0].set_clip_on(False)
l2[0].set_clip_on(False)
plt.xlabel("Time (μs)", fontsize=15)
plt.ylabel("Excited State Population")
plt.ylim(0, 1)
plt.legend(bbox_to_anchor=(1, 1), fontsize=15)
plt.title("Brown noise (Δ=0)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Brown noise (Δ=0)')

# %% [markdown]
# # Lorentzian Noise

# %%
set_data("lorentzian_noise_Δ0_Δ̃04_width1_center0", "1427_27")
set_data("lorentzian_noise_Δ0_Δ̃04_width1_center10", "1432_54")
set_data("lorentzian_noise_Δ0_Δ̃04_width100_center0", "1437_10")
set_data("lorentzian_noise_Δ0_Δ̃04_width100_center10", "1441_49")
set_data("lorentzian_noise_ΔJ_Δ̃04_width1_center0", ["1445_44", "1453_14"])
set_data("lorentzian_noise_ΔJ_Δ̃04_width1_center18.5", "1450_00")
set_data("lorentzian_noise_ΔJ_Δ̃04_width5_center0", "1502_04")
set_data("lorentzian_noise_ΔJ_Δ̃04_width5_center18.5", "1457_29")

# %%
l1 = plt.plot(data["lorentzian_noise_Δ0_Δ̃04_width1_center0-x"], data["lorentzian_noise_Δ0_Δ̃04_width1_center0-y"], 
              marker="o", label="Δ̃=0.4, γ=1 kHz, f0=0 kHz")
l2 = plt.plot(data["lorentzian_noise_Δ0_Δ̃04_width1_center10-x"], data["lorentzian_noise_Δ0_Δ̃04_width1_center10-y"], 
              marker="o", label="Δ̃=0.4, γ=1 kHz, f0=10 kHz")
l3 = plt.plot(data["lorentzian_noise_Δ0_Δ̃04_width100_center0-x"], data["lorentzian_noise_Δ0_Δ̃04_width100_center0-y"], 
              marker="o", label="Δ̃=0.4, γ=100 kHz, f0=0 kHz")
l4 = plt.plot(data["lorentzian_noise_Δ0_Δ̃04_width100_center10-x"], data["lorentzian_noise_Δ0_Δ̃04_width100_center10-y"], 
              marker="o", label="Δ̃=0.4, γ=100 kHz, f0=10 kHz")
l1[0].set_clip_on(False)
l2[0].set_clip_on(False)
l3[0].set_clip_on(False)
l4[0].set_clip_on(False)
plt.xlabel("Time (μs)", fontsize=15)
plt.ylabel("Excited State Population")
plt.ylim(0, 1)
plt.legend(bbox_to_anchor=(1, 1), fontsize=15)
plt.title("Lorentzian Noise (Δ=0)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Lorentzian Noise (Δ=0)')

# %%
l1 = plt.plot(data["lorentzian_noise_ΔJ_Δ̃04_width1_center0-x"], data["lorentzian_noise_ΔJ_Δ̃04_width1_center0-y"], 
              marker="o", label="Δ̃=0.4, γ=1 kHz, f0=0 kHz")
l2 = plt.plot(data["lorentzian_noise_ΔJ_Δ̃04_width1_center18.5-x"], data["lorentzian_noise_ΔJ_Δ̃04_width1_center18.5-y"], 
              marker="o", label="Δ̃=0.4, γ=1 kHz, f0=18.5 kHz")
l3 = plt.plot(data["lorentzian_noise_ΔJ_Δ̃04_width5_center0-x"], data["lorentzian_noise_ΔJ_Δ̃04_width5_center0-y"], 
              marker="o", label="Δ̃=0.4, γ=5 kHz, f0=0 kHz")
l4 = plt.plot(data["lorentzian_noise_ΔJ_Δ̃04_width5_center18.5-x"], data["lorentzian_noise_ΔJ_Δ̃04_width5_center18.5-y"], 
              marker="o", label="Δ̃=0.4, γ=5 kHz, f0=18.5 kHz")
l1[0].set_clip_on(False)
l2[0].set_clip_on(False)
l3[0].set_clip_on(False)
l4[0].set_clip_on(False)
plt.xlabel("Time (μs)", fontsize=15)
plt.ylabel("Excited State Population")
plt.ylim(0, 1)
plt.xlim(t[0], t[-1])
plt.legend(bbox_to_anchor=(1, 1), fontsize=15)
plt.title("Lorentzian Noise (Δ=J)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Lorentzian Noise (Δ=J)')
