# %%
import numpy as np
import h5py as h
import matplotlib.pyplot as plt
import matplotlib
from qutip import *

# %%
matplotlib.rcParams.update(
        {"font.family": "Georgia",
         "font.variant": "normal",
         "font.weight": "roman",
         "xtick.labelsize": 15,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.right": True,
         "ytick.direction": "in",
         "ytick.labelsize": 15,
#          "axes.prop_cycle": (matplotlib.cycler("color", ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])),
         "axes.labelsize": 15,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)

# %%
s = "scan_data"
d = h.File("data/2021-12-15/SingleIonVAET/1556_44.h5", "r")[s]
d_hot = h.File("data/2021-12-15/SingleIonVAET/1636_43.h5", "r")[s]
y,x = list(d.keys()); list(d.keys())
# Out:
# ['SingleIonVAET-ion number:0', 'SingleIonVAET.nu_eff']

# %%
d_vaet = h.File("data/2021-12-15/SingleIonVAET/1615_43.h5", "r")[s]
d_rotated = h.File("data/2021-12-15/SingleIonVAET/1447_07.h5", "r")[s]
d_detuned = h.File("data/2021-12-15/SingleIonVAET/1457_19.h5", "r")[s]
d_bad_vaet = h.File("data/2021-12-15/SingleIonVAET/1531_20.h5", "r")[s]
y,x = list(d_vaet.keys()); list(d_vaet.keys())
# Out:
# ['SingleIonVAET-ion number:0', 'SingleIonVAET.duration']

# %%
plt.plot(d_rotated[x][()], d_rotated[y][()], marker="o")
plt.plot(d_detuned[x][()], d_detuned[y][()], marker="o")
plt.xlim(0, 4e-4)
plt.xlabel("duration (s)", fontsize=20)
plt.ylabel("Excitation", fontsize=20)
# Out:
# Text(0, 0.5, 'Excitation')

# %%
plt.plot(np.linspace(-40, 40, 120), d[y][()])
plt.plot(np.linspace(-40, 40, len(d_hot[y][()])), d_hot[y][()])
plt.xlabel(r"$ν_{eff}$ (kHz)", fontsize=20)
plt.ylabel("Excitation", fontsize=20)
# Out:
# Text(0, 0.5, 'Excitation')

# %%
plt.plot(d_vaet[x][()], d_vaet[y][()], marker="o")
plt.plot(d_bad_vaet[x][()], d_bad_vaet[y][()], marker="o")
plt.xlabel("duration (s)", fontsize=20)
plt.ylabel("Excitation", fontsize=20)
# Out:
# Text(0, 0.5, 'Excitation')
