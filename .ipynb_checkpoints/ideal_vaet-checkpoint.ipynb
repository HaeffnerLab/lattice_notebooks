# %%
using Revise
using QuantumOptics
using LaTeXStrings
import PyPlot
import StochasticDiffEq
const plt = PyPlot
# Out:
# PyPlot

# %%
# set some plot configs
plt.matplotlib.rc("xtick", top=false)
plt.matplotlib.rc("ytick", right=false, left=false)
plt.matplotlib.rc("axes", labelsize=20, titlesize=20, grid=true)
plt.matplotlib.rc("axes", linewidth=2)
plt.matplotlib.rc("grid", alpha=0.25, linestyle="--")
plt.matplotlib.rc("font", family="Palatino", weight="medium")
plt.matplotlib.rc("figure", figsize=(8,4))
plt.matplotlib.rc("xtick.major", width=2)
plt.matplotlib.rc("ytick.major", width=2)

# %%
# construct bases
sb = SpinBasis(1//2)
vb = FockBasis(10)
cb = sb ⊗ vb;

# %%
# Electronic ground state in Y-basis
ψg = (1/√2) * (spindown(sb) - im*spinup(sb))
# Electronic excited state in Y-basis
ψe = (1/√2) * (spindown(sb) + im*spinup(sb))
# Inital state
ψi = ψg ⊗ fockstate(vb, 0);

# %%
# Bare rotated-basis, single-ion, VAET Hamiltonian
H(J, Δ, κ, ν) = 2π * J/2 * sigmax(sb) ⊗ one(vb) + 2π * Δ/2 * sigmay(sb) ⊗ one(vb) + 2π * κ/2 * sigmay(sb) ⊗ (create(vb) + destroy(vb)) + 2π * ν * one(sb) ⊗ number(vb)
# Out:
# H (generic function with 1 method)

# %%
# Measurement function
fout(t, ψ) = expect((ψe ⊗ ψe') ⊗ one(vb), ψ)
# Out:
# fout (generic function with 1 method)

# %% [markdown]
# # Master Equation

# %%
# σy noise operator for use with Lindblad master equation
J(Γ) = [√(2π * Γ) * sigmay(sb) ⊗ one(vb)]
# Out:
# J (generic function with 1 method)

# %%
# Look at coherent VAET dynamics for different VAET detunings
for ν in range(2, stop=2.5, length=6)
    tout, sol = timeevolution.schroedinger(collect(0:0.01:6.5), ψi, H(1, 2, 1, ν), fout=fout)
    plt.plot(tout, sol, label="ν=2π×$ν")
end
plt.ylim(0, 1)
plt.xlim(tout[1], tout[end])
plt.legend(bbox_to_anchor=(1, 1))
plt.xlabel("time (1/J)")
plt.ylabel(L"𝔼(|↑⟩_y⟨↑|)")
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 800x400 with 1 Axes>)

# %%
# Look at VAET dynamics for various white noise strengths
for Γ in range(0, stop=0.05, length=10)
    tout, sol = timeevolution.master(collect(0:0.1:40), ψi, H(1, 2, 1, 2.15), J(Γ), fout=fout, reltol=1e-9, abstol=1e-8)
    plt.plot(tout, sol, label="Γ=2π×$(round(Γ,digits=3))")
end
plt.ylim(0, 1)
plt.xlim(tout[1], tout[end])
plt.legend(bbox_to_anchor=(1, 1))
plt.xlabel("time (1/J)")
plt.ylabel(L"𝔼(|↑⟩_y⟨↑|)")
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 800x400 with 1 Axes>)

# %%
# Look at VAET dynamics for various white noise strengths at long run times
for Γ in range(0.1, stop=1, length=10)
    tout, sol = timeevolution.master(collect(0:0.1:200), ψi, H(1, 2, 1, 2.15), J(Γ), fout=fout)
    plt.plot(tout, sol, label="Γ=2π×$(round(Γ,digits=3))")
end
plt.ylim(0, 1)
plt.xlim(tout[1], tout[end])
plt.legend(bbox_to_anchor=(1, 1))
plt.xlabel("time (1/J)")
plt.ylabel(L"𝔼(|↑⟩_y⟨↑|)")
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 800x400 with 1 Axes>)

# %%
# demonstration of ENAQT phenomena
for Γ in range(0.05, stop=1, length=10)
    tout, sol = timeevolution.master(collect(0:0.1:25), ψi, H(1, 2, 0, 2.15), J(Γ), fout=fout)
    plt.plot(tout, sol, label="Γ=2π×$(round(Γ,digits=3))")
end
plt.ylim(0.3, 0.65)
plt.xlim(tout[1], tout[end])
plt.legend(bbox_to_anchor=(1, 1))
plt.xlabel("time (1/J)")
plt.ylabel(L"𝔼(|↑⟩_y⟨↑|)")
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 800x400 with 1 Axes>)

# %%
# ENAQT and resonant VAET are not compatible here
for Γ in range(0.05, stop=1, length=10)
    tout, sol = timeevolution.master(collect(0:0.1:25), ψi, H(1, 2, 1, 2.15), J(Γ), fout=fout)
    plt.plot(tout, sol, label="Γ=2π×$(round(Γ,digits=3))")
end
plt.ylim(0.3, 0.65)
plt.xlim(tout[1], tout[end])
plt.legend(bbox_to_anchor=(1, 1))
plt.xlabel("time (1/J)")
plt.ylabel(L"𝔼(|↑⟩_y⟨↑|)")
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 800x400 with 1 Axes>)

# %%
# integrated excited state population for a resonant VAET interaction as a function of white noise strength
Γlist = [range(0, stop=0.15, length=20); range(0.15, stop=1.5, length=50)]
intpop = []
for Γ in Γlist
    _, sol = timeevolution.master(collect(0:0.1:100), ψi, H(1, 2, 1, 2.15), J(Γ), fout=fout)
    push!(intpop, sum(real.(sol)))
end
plt.plot(Γlist, intpop)
plt.xlabel("Γ/2π")
plt.ylabel(L"\int_0^t dt 𝔼(|↑⟩_y⟨↑|)")
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 800x400 with 1 Axes>)

# %%
# What about ENAQT and detuend VAET?
fig, ax = plt.subplots(2, 1, sharex=true, figsize=(10,5))
for Γ in range(0, stop=1, length=10)
    tout, sol = timeevolution.master(collect(0:0.01:25), ψi, H(1, 2, 1, 3.15), J(Γ), fout=fout)
    tout, sol1 = timeevolution.master(collect(0:0.01:25), ψi, H(1, 2, 0, 3.15), J(Γ), fout=fout)
    ax[2,1].plot(tout, sol, label="Γ=2π×$(round(Γ,digits=3))")
    ax[1,1].plot(tout, sol1, label="Γ=2π×$(round(Γ,digits=3))")
end
plt.ylim(0, 0.6)
plt.xlim(tout[1], tout[end])
ax[1,1].legend(bbox_to_anchor=(1, 1))
plt.xlabel("time (1/J)")
ax[1,1].set_ylabel(L"𝔼(|↑⟩_y⟨↑|)")
plt.ylabel(L"𝔼(|↑⟩_y⟨↑|)")
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %% [markdown]
# # Stochastic Schroedinger Equation

# %%
# Stochastic term for Hamitonian
Hs(δΔ) = (sqrt(2π * δΔ) / 2) * sigmay(sb) ⊗ one(vb)
# Out:
# Hs (generic function with 1 method)

# %%
Ntraj = 250
tspan = 0:0.1:40
y_avg1 = zero(tspan)
y_avg2 = zero(tspan)
y_avg3 = zero(tspan)
for i in 1:Ntraj
    t, y1 = stochastic.schroedinger(tspan, ψi, H(1, 2, 1, 2.15), Hs(0.01), fout=fout, dt=1e-5, normalize_state=true)
    t, y2 = stochastic.schroedinger(tspan, ψi, H(1, 2, 1, 2.15), Hs(0.05), fout=fout, dt=1e-5, normalize_state=true)
    t, y3 = stochastic.schroedinger(tspan, ψi, H(1, 2, 1, 2.15), Hs(0.1), fout=fout, dt=1e-5, normalize_state=true)
    y_avg1 .+= real.(y1)./Ntraj
    y_avg2 .+= real.(y2)./Ntraj
    y_avg3 .+= real.(y3)./Ntraj
end

# %%
tout, sol1 = timeevolution.master(collect(0:0.1:40), ψi, H(1, 2, 1, 2.15), J(0.01/4), fout=fout, reltol=1e-9, abstol=1e-8)
tout, sol2 = timeevolution.master(collect(0:0.1:40), ψi, H(1, 2, 1, 2.15), J(0.05/4), fout=fout, reltol=1e-9, abstol=1e-8)
tout, sol3 = timeevolution.master(collect(0:0.1:40), ψi, H(1, 2, 1, 2.15), J(0.1/4), fout=fout, reltol=1e-9, abstol=1e-8)
fig, ax = plt.subplots(1, 3, sharey=true, figsize=(15,3))
ax[1,1].plot(tout, sol1)
ax[1,1].plot(tspan, y_avg1, ls="--")
ax[2,1].plot(tout, sol2)
ax[2,1].plot(tspan, y_avg2, ls="--")
ax[3,1].plot(tout, sol3, label="master eq.")
ax[3,1].plot(tspan, y_avg3, ls="--", label="stochastic Schroedinger eq.")
ax[1,1].set_title(L"Γ = 2π × \frac{0.01}{4}" * "\n" * L"δΔ = \sqrt{2π \times 0.01}", fontsize=15)
ax[2,1].set_title(L"Γ = 2π × \frac{0.05}{4}" * "\n" * L"δΔ = \sqrt{2\pi \times 0.05}", fontsize=15)
ax[3,1].set_title(L"Γ = 2π × \frac{0.1}{4}" * "\n" * L"δΔ = \sqrt{2\pi \times 0.1}", fontsize=15)
ax[1,1].set_ylabel(L"𝔼(|↑⟩_y⟨↑|)")
ax[2,1].set_xlabel("time (1/J)")
ax[1,1].set_ylim(0, 1); ax[2,1].set_ylim(0, 1); ax[3,1].set_ylim(0, 1)
ax[1,1].set_xlim(tout[1], tout[end]); ax[2,1].set_xlim(tout[1], tout[end]); ax[3,1].set_xlim(tout[1], tout[end])
ax[3,1].legend()
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 1500x300 with 3 Axes>)

# %%
# Effect on Rabi Oscillations
HR = 2π/2 * sigmax(sb)
HsR(δ) = (sqrt(2π * δ) / 2) * sigmax(sb)
JR(Γ) = [√(2π * Γ) * sigmay(sb)]
foutR(t,psi) = expect(dm(spinup(sb)), psi)
Ntraj = 250
tspan = 0:0.1:40
y_avgR1 = zero(tspan)
y_avgR2 = zero(tspan)
y_avgR3 = zero(tspan)
for i in 1:Ntraj
    t, y1 = stochastic.schroedinger(tspan, spindown(sb), HR, HsR(0.01), fout=foutR, dt=1e-5, normalize_state=true)
    t, y2 = stochastic.schroedinger(tspan, spindown(sb), HR, HsR(0.05), fout=foutR, dt=1e-5, normalize_state=true)
    t, y3 = stochastic.schroedinger(tspan, spindown(sb), HR, HsR(0.1), fout=foutR, dt=1e-5, normalize_state=true)
    y_avgR1 .+= real.(y1)./Ntraj
    y_avgR2 .+= real.(y2)./Ntraj
    y_avgR3 .+= real.(y3)./Ntraj
end

# %%
tout, sol1R = timeevolution.master(collect(0:0.1:40), spindown(sb), HR, JR(0.01/2), fout=foutR)
tout, sol2R = timeevolution.master(collect(0:0.1:40), spindown(sb), HR, JR(0.05/2), fout=foutR)
tout, sol3R = timeevolution.master(collect(0:0.1:40), spindown(sb), HR, JR(0.1/2), fout=foutR)
fig, ax = plt.subplots(1, 3, sharey=true, figsize=(15,3))
ax[1,1].plot(tout, sol1R)
ax[1,1].plot(tspan, y_avgR1, ls="--")
ax[1,1].plot(tspan, @.(0.5 + 0.5exp(-2π * 0.01/2 * tspan)))
ax[2,1].plot(tout, sol2R)
ax[2,1].plot(tspan, y_avgR2, ls="--")
ax[2,1].plot(tspan, @.(0.5 + 0.5exp(-2π * 0.05/2 * tspan)))
ax[3,1].plot(tout, sol3R, label="master eq.")
ax[3,1].plot(tspan, y_avgR3, ls="--", label="stochastic Schroedinger eq.")
ax[3,1].plot(tspan, @.(0.5 + 0.5exp(-2π * 0.1/2 * tspan)), label=L"\frac{1 + exp(-2π×Γt/2)}{2}")
ax[1,1].set_title(L"Γ = 2π × \frac{0.01}{2}" * "\n" * L"δΔ = \sqrt{2π \times 0.01}", fontsize=15)
ax[2,1].set_title(L"Γ = 2π × \frac{0.05}{2}" * "\n" * L"δΔ = \sqrt{2\pi \times 0.05}", fontsize=15)
ax[3,1].set_title(L"Γ = 2π × \frac{0.1}{2}" * "\n" * L"δΔ = \sqrt{2\pi \times 0.1}", fontsize=15)
ax[1,1].set_ylabel(L"𝔼(|↑⟩_y⟨↑|)")
ax[2,1].set_xlabel("time (1/J)")
ax[1,1].set_ylim(0, 1); ax[2,1].set_ylim(0, 1); ax[3,1].set_ylim(0, 1)
ax[1,1].set_xlim(tout[1], tout[end]); ax[2,1].set_xlim(tout[1], tout[end]); ax[3,1].set_xlim(tout[1], tout[end])
ax[3,1].legend()
plt.suptitle(L"Rabi Oscillations with $\sigma_x$ Noise", y=1.25, fontsize=20)
plt.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 1500x300 with 3 Axes>)

# %% [markdown]
# # Lorentzian Noise

# %%
Nc = 10
κ = 1.0
n = 4
Δ = 5.0κ

basis = FockBasis(Nc)
a = destroy(basis)
Ht = -Δ*dagger(a)*a
Jt = [sqrt(2κ)*a]

ρ₀ = fockstate(basis, n) ⊗ dagger(fockstate(basis, n))

dτ = 0.001
τmax = 1000
τ = [0:dτ:τmax;]
corr = timecorrelations.correlation(τ, ρ₀, Ht, Jt, dagger(a) + a,  dagger(a) + a);

# %%
ω, spec = timecorrelations.correlation2spectrum(τ, corr; normalize_spec=true);

# %%
coth(-1e-4)
# Out:
# -10000.000033333332

# %%
corr_an = @.(im * sin(Δ*τ) * exp(-κ*abs(τ)))#exp(-#n.*exp.(-1.0im*Δ.*τ).*exp.(-κ.*τ)
spec_an = 2n*κ./((Δ .+ ω).^2 .+ κ^2) + 2.5n*κ./((Δ .- ω).^2 .+ κ^2) #.* coth.(ω .* 1e4 ./ 2)
spec_an ./= maximum(spec_an);

# %%
plt.figure(figsize=(9, 3))
plt.subplot(121)
plt.plot(ω, spec)
plt.plot(ω, spec_an, ls="dashed")
plt.xlim(-20, 20)
# plt.ylim(-2, 2)
plt.xlabel("freq.")
plt.ylabel("spectrum", fontsize=15)
plt.subplot(122)
# ax1 = plt.twinx()
plt.plot(τ[1:4000], real(corr[1:4000]), label="numerical (Real)")
plt.plot(τ[1:4000], imag(corr[1:4000]), label="numerical (Imaginary)")
plt.plot(τ[1:4000], real(corr_an[1:4000]), ls="dashed", label="analytical (Real)")
plt.plot(τ[1:4000], imag(corr_an[1:4000]), ls="dashed", label="analytical (Imaginary)")
plt.xlabel("time")
plt.ylabel(L"⟨a^{\dagger}(t)a(0)⟩", fontsize=15)
plt.legend()
plt.suptitle(L"L[ρ] = 2κ(nρn - \frac{1}{2}\{n^2, ρ\})")
# Out:
# PyPlot.Figure(PyObject <Figure size 900x300 with 2 Axes>)
# PyObject Text(0.5, 0.98, '$L[ρ] = 2κ(nρn - \\frac{1}{2}\\{n^2, ρ\\})$')

# %%
Jm(γ) = [√(2π*γ) * one(sb) ⊗ number(vb)];

# %%
# H(J, Δ, κ, ν)

# %%
n̄ = 0.025
T = 1 / (log((1 / n̄) + 1))
hf = create(basis) * destroy(basis)
if n̄ ≡ 0
    ρ₀ = fockstate(basis, 0) ⊗ dagger(fockstate(basis, 0))
else
    ρ₀ = thermalstate(hf, T)
end

fig, ax = plt.subplots(1,3, figsize=(15,4), sharey=true)
# for γ in 0:0.002:0.01
#     tout, sol = timeevolution.master(collect(0:0.01:10), ψi, H(1, 0, 1, 0), Jm(γ), fout=fout);
#     ax[1,1].plot(tout, sol, label="Γ=2π×$γ")
# end
for γ in 0.1:0.2:1
    tout, sol = timeevolution.master(collect(0:0.01:10), ψi, H(1, 0, 2, 2), Jm(γ), fout=fout);
    ax[2,1].plot(tout, 1 .- sol, label="Γ=2π×$γ")
end
# for γ in range(10, stop=100, length=5)
#     tout, sol = timeevolution.master(collect(0:0.01:10), ψi, H(1, 0, 1, 0), Jm(γ), fout=fout);
#     ax[3,1].plot(tout, sol, label="Γ=2π×$(round(γ,digits=3))")
# end
ax[1,1].set_title("Strong")
ax[2,1].set_title("Intermediate")
ax[3,1].set_title("Weak")
ax[1,1].set_ylabel("Excitation")
ax[2,1].set_xlabel("time (1/J)")
ax[1,1].legend(loc=1)
ax[2,1].legend(loc=1)
ax[3,1].legend(loc=1)

# %%
fig, ax = plt.subplots(1,3, figsize=(15,4), sharey=true)
for γ in 0:0.002:0.01
    tout, sol = timeevolution.master(collect(0:0.01:10), ψi, H(1, 0, 1, 1), Jm(γ), fout=fout);
    ax[1,1].plot(tout, sol, label="Γ=2π×$γ")
end
for γ in 0.1:0.2:1
    tout, sol = timeevolution.master(collect(0:0.01:10), ψi, H(1, 0, 1, 1), Jm(γ), fout=fout);
    ax[2,1].plot(tout, sol, label="Γ=2π×$γ")
end
for γ in range(10, stop=100, length=5)
    tout, sol = timeevolution.master(collect(0:0.01:10), ψi, H(1, 0, 1, 1), Jm(γ), fout=fout);
    ax[3,1].plot(tout, sol, label="Γ=2π×$(round(γ,digits=3))")
end
ax[1,1].set_title("Strong")
ax[2,1].set_title("Intermediate")
ax[3,1].set_title("Weak")
ax[1,1].set_ylabel("Excitation")
ax[2,1].set_xlabel("time (1/J)")
ax[1,1].legend(loc=1)
ax[2,1].legend(loc=1)
ax[3,1].legend(loc=1)
# Out:
# PyPlot.Figure(PyObject <Figure size 1500x400 with 3 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x214d023d0>

# %%
fig, ax = plt.subplots(1,3, figsize=(15,4), sharey=true)
for γ in 0:0.002:0.01
    tout, sol = timeevolution.master(collect(0:0.01:10), ψi, H(1, 0, 1, 2), Jm(γ), fout=fout);
    ax[1,1].plot(tout, sol, label="Γ=2π×$γ")
end
for γ in 0.1:0.2:1
    tout, sol = timeevolution.master(collect(0:0.01:10), ψi, H(1, 0, 1, 2), Jm(γ), fout=fout);
    ax[2,1].plot(tout, sol, label="Γ=2π×$γ")
end
for γ in range(10, stop=100, length=5)
    tout, sol = timeevolution.master(collect(0:0.01:10), ψi, H(1, 0, 1, 2), Jm(γ), fout=fout);
    ax[3,1].plot(tout, sol, label="Γ=2π×$(round(γ,digits=3))")
end
ax[1,1].set_title("Strong")
ax[2,1].set_title("Intermediate")
ax[3,1].set_title("Weak")
ax[1,1].set_ylabel("Excitation")
ax[2,1].set_xlabel("time (1/J)")
ax[1,1].legend(loc=1)
ax[2,1].legend(loc=1)
ax[3,1].legend(loc=1)
# Out:
# PyPlot.Figure(PyObject <Figure size 1500x400 with 3 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x213c24190>

# %%
Δ=-2
spec_an = 2n*κ./((Δ .+ ω).^2 .+ κ^2)
fig, ax = plt.subplots()
ax.plot(ω, spec_an)
ax.set_xlim(-10,10)
plt.grid(false)
ax.spines["right"].set_visible(false)
ax.spines["top"].set_visible(false)
ax.spines["left"].set_visible(false)
ax.set_yticklabels([])
ax.set_xticks([2])
# Out:
# PyPlot.Figure(PyObject <Figure size 800x400 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.axis.XTick object at 0x213c69a50>

# %%
H(J, Δ, κ, ν, κ2, ν2) = (2π * J/2 * sigmax(sb) ⊗ one(vb) ⊗ one(vb) + 
                         2π * Δ/2 * sigmay(sb) ⊗ one(vb) ⊗ one(vb) + 
                         2π * κ/2 * sigmay(sb) ⊗ (create(vb) + destroy(vb)) ⊗ one(vb) + 
                         2π * ν * one(sb) ⊗ number(vb) ⊗ one(vb)  + 
                         2π * κ2/2 * sigmay(sb) ⊗ one(vb) ⊗ (create(vb) + destroy(vb)) + 
                         2π * ν2 * one(sb) ⊗ one(vb) ⊗ number(vb))
Jm2(γ) = [√(2π*γ) * one(sb) ⊗ one(vb) ⊗ number(vb)]
ψi2 = ψg ⊗ fockstate(vb, 0) ⊗ fockstate(vb, 0)
fout2(t, ψ) = expect((ψe ⊗ ψe') ⊗ one(vb) ⊗ one(vb), ψ);

# %%
tout, sol = timeevolution.master(collect(0:0.01:10), ψi2, H(1, 2, 1, 3.15, 1, 1), Jm2(0.1), fout=fout2);

# %%
tout, sol2 = timeevolution.master(collect(0:0.01:10), ψi2, H(1, 2, 1, 3.15, 1, 1), Jm2(0.5), fout=fout2);
tout, sol3 = timeevolution.master(collect(0:0.01:10), ψi2, H(1, 2, 1, 3.15, 1, 1), Jm2(1), fout=fout2);
tout, sol4 = timeevolution.master(collect(0:0.01:10), ψi2, H(1, 2, 1, 3.15, 1, 10), Jm2(1), fout=fout2);

# %%
plt.plot(tout, sol, label="γ=2π×0.1, ν₂=1")
plt.plot(tout, sol2, label="γ=2π×0.5, ν₂=1")
plt.plot(tout, sol3, label="γ=2π×1.0, ν₂=1")
plt.plot(tout, sol4, label="γ=2π×1.0, ν₂=10")
plt.xlim(tout[1], tout[end])
plt.ylim(0, 1)
plt.xlabel("time (1/J)")
plt.ylabel(L"𝔼(|↑⟩_y⟨↑|)")
plt.legend()
# Out:
# PyPlot.Figure(PyObject <Figure size 800x400 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x156babed0>
