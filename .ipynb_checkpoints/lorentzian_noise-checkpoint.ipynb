# %%
using Revise
using QuantumOptics
using LaTeXStrings
import PyPlot
import StochasticDiffEq
const plt = PyPlot
# Out:
# ┌ Info: Precompiling PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# └ @ Base loading.jl:1273
# ┌ Warning: Module Conda with build ID 3077367470043487 is missing from the cache.
# │ This may mean Conda [8f4d0f93-b110-5947-807f-2305c1781a2d] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1011
# ┌ Warning: Module Conda with build ID 3077367470043487 is missing from the cache.
# │ This may mean Conda [8f4d0f93-b110-5947-807f-2305c1781a2d] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1011
# ┌ Info: Skipping precompilation since __precompile__(false). Importing PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee].
# └ @ Base loading.jl:1028
# ┌ Info: Precompiling PyCall [438e738f-606a-5dbb-bf0a-cddfbfd45ab0]
# └ @ Base loading.jl:1273
# ┌ Warning: Module Conda with build ID 3077367470043487 is missing from the cache.
# │ This may mean Conda [8f4d0f93-b110-5947-807f-2305c1781a2d] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1011
# ┌ Info: Skipping precompilation since __precompile__(false). Importing PyCall [438e738f-606a-5dbb-bf0a-cddfbfd45ab0].
# └ @ Base loading.jl:1028
# PyPlot

# %%
# set some plot configs
plt.matplotlib.rc("xtick", top=false)
plt.matplotlib.rc("ytick", right=false, left=false)
plt.matplotlib.rc("axes", labelsize=20, titlesize=20, grid=true)
plt.matplotlib.rc("axes", linewidth=2)
plt.matplotlib.rc("grid", alpha=0.25, linestyle="--")
plt.matplotlib.rc("font", family="Palatino", weight="medium")
plt.matplotlib.rc("figure", figsize=(8,4))
plt.matplotlib.rc("xtick.major", width=2)
plt.matplotlib.rc("ytick.major", width=2)

# %%
Nc = 20
Γ = 0.5
n̄ = 10
νeff = 10.0

basis = FockBasis(Nc)
a = destroy(basis)
Ht = -νeff * dagger(a) * a
Jtt1(Γ) = [sqrt(2Γ) * a]
Jtt2(Γ) = [sqrt(2Γ) * dagger(a) * a]
Jt3 = [sqrt(2Γ * (n̄ + 1)) * a, sqrt(2Γ * n̄) * dagger(a)]
Jtt4(Γ) = [sqrt(2Γ) * (dagger(a) + a)^2]

T = 1 / (log((1 / n̄) + 1))
hf = create(basis) * destroy(basis)
if n̄ ≡ 0
    ρ₀ = fockstate(basis, 0) ⊗ dagger(fockstate(basis, 0))
else
    ρ₀ = thermalstate(hf, T)
end
dτ = 0.001
τmax = 100
τ = [0:dτ:τmax;]
corr11 = timecorrelations.correlation(τ, ρ₀, Ht, Jtt4(1), dagger(a) + a,  dagger(a) + a)
corr12 = timecorrelations.correlation(τ, ρ₀, Ht, Jtt1(1), dagger(a) + a,  dagger(a) + a)
corr21 = timecorrelations.correlation(τ, ρ₀, Ht, Jtt4(5), dagger(a) + a,  dagger(a) + a)
corr22 = timecorrelations.correlation(τ, ρ₀, Ht, Jtt1(5), dagger(a) + a,  dagger(a) + a)
corr31 = timecorrelations.correlation(τ, ρ₀, Ht, Jtt4(10), dagger(a) + a,  dagger(a) + a)
corr32 = timecorrelations.correlation(τ, ρ₀, Ht, Jtt1(10), dagger(a) + a,  dagger(a) + a)
# corr3 = timecorrelations.correlation(τ, ρ₀, Ht, Jt3, dagger(a) + a,  dagger(a) + a);
# Out:
# ┌ Warning: Interrupted. Larger maxiters is needed.
# └ @ DiffEqBase /Users/joe/.julia/packages/DiffEqBase/H1xRL/src/integrator_interface.jl:329

# %%
ω, spec11 = timecorrelations.correlation2spectrum(τ, corr11; normalize_spec=false)
ω, spec12 = timecorrelations.correlation2spectrum(τ, corr12; normalize_spec=false)
ω, spec21 = timecorrelations.correlation2spectrum(τ, corr21; normalize_spec=false)
ω, spec22 = timecorrelations.correlation2spectrum(τ, corr22; normalize_spec=false)
ω, spec31 = timecorrelations.correlation2spectrum(τ, corr31; normalize_spec=false)
ω, spec32 = timecorrelations.correlation2spectrum(τ, corr32; normalize_spec=false)
# ω, spec3 = timecorrelations.correlation2spectrum(τ, corr3; normalize_spec=false);

# %%
# corr_an = @.(im * sin(Δ*τ) * exp(-κ*abs(τ)))#exp(-#n.*exp.(-1.0im*Δ.*τ).*exp.(-κ.*τ)
# spec_an = 2n*κ./((Δ .+ ω).^2 .+ κ^2) + 2.5n*κ./((Δ .- ω).^2 .+ κ^2) #.* coth.(ω .* 1e4 ./ 2)
# spec_an ./= maximum(spec_an);

# %%
plt.figure(figsize=(9, 3))
plt.subplot(131)
plt.plot(ω, spec11)
plt.plot(ω, spec12, ls="dashed", color="k")
plt.plot(ω, spec21)
plt.plot(ω, spec22, ls="dashed", color="k")
plt.plot(ω, spec31)
plt.plot(ω, spec32, ls="dashed", color="k")
plt.xlim(-20, 20)
plt.xlabel("freq.", fontsize=15)
plt.title(L"\mathcal{FT}\{⟨x^{\dagger}(t)x(0)⟩\}", fontsize=15)

plt.subplot(132)
plt.plot(τ, real(corr11))
plt.plot(τ, real(corr12), ls="--", color="k")
plt.plot(τ, real(corr21))
plt.plot(τ, real(corr22), ls="--", color="k")
plt.plot(τ, real(corr31))
plt.plot(τ, real(corr32), ls="--", color="k")
plt.xlim(0, 2)
plt.xlabel("time", fontsize=15)
plt.title(L"Re\{⟨x^{\dagger}(t)x(0)⟩\}", fontsize=15)

plt.subplot(133)
plt.plot(τ, imag(corr11), label="Γ=2π×1")
plt.plot(τ, imag(corr12), ls="--", color="k")
plt.plot(τ, imag(corr21), label="Γ=2π×5")
plt.plot(τ, imag(corr22), ls="--", color="k")
plt.plot(τ, imag(corr31), label="Γ=2π×10")
plt.plot(τ, imag(corr32), label=L"D[ρ] → Γ[aρa^† - a^†aρ] + h.c.", ls="--", color="k")
plt.xlim(0, 2)
plt.xlabel("time", fontsize=15)
plt.title(L"Im\{⟨x^{\dagger}(t)x(0)⟩\}", fontsize=15)
plt.legend(bbox_to_anchor=(1, 1))

# plt.suptitle(L"⟨x^{\dagger}(t)x(0)⟩", fontsize=20, y=1.05)
# Out:
# PyError ($(Expr(:escape, :(ccall(#= /Users/joe/.julia/packages/PyCall/zqDXB/src/pyfncall.jl:43 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'ValueError'>
# ValueError('x and y must have same first dimension, but have shapes (100001,) and (87119,)')
#   File "/Users/joe/anaconda3/envs/qutip/lib/python3.7/site-packages/matplotlib/pyplot.py", line 2811, in plot
#     is not None else {}), **kwargs)
#   File "/Users/joe/anaconda3/envs/qutip/lib/python3.7/site-packages/matplotlib/__init__.py", line 1810, in inner
#     return func(ax, *args, **kwargs)
#   File "/Users/joe/anaconda3/envs/qutip/lib/python3.7/site-packages/matplotlib/axes/_axes.py", line 1611, in plot
#     for line in self._get_lines(*args, **kwargs):
#   File "/Users/joe/anaconda3/envs/qutip/lib/python3.7/site-packages/matplotlib/axes/_base.py", line 393, in _grab_next_args
#     yield from self._plot_args(this, kwargs)
#   File "/Users/joe/anaconda3/envs/qutip/lib/python3.7/site-packages/matplotlib/axes/_base.py", line 370, in _plot_args
#     x, y = self._xy_from_xy(x, y)
#   File "/Users/joe/anaconda3/envs/qutip/lib/python3.7/site-packages/matplotlib/axes/_base.py", line 231, in _xy_from_xy
#     "have shapes {} and {}".format(x.shape, y.shape))
#
#
# Stacktrace:
#  [1] pyerr_check at /Users/joe/.julia/packages/PyCall/zqDXB/src/exception.jl:60 [inlined]
#  [2] pyerr_check at /Users/joe/.julia/packages/PyCall/zqDXB/src/exception.jl:64 [inlined]
#  [3] _handle_error(::String) at /Users/joe/.julia/packages/PyCall/zqDXB/src/exception.jl:81
#  [4] macro expansion at /Users/joe/.julia/packages/PyCall/zqDXB/src/exception.jl:95 [inlined]
#  [5] #110 at /Users/joe/.julia/packages/PyCall/zqDXB/src/pyfncall.jl:43 [inlined]
#  [6] disable_sigint at ./c.jl:446 [inlined]
#  [7] __pycall! at /Users/joe/.julia/packages/PyCall/zqDXB/src/pyfncall.jl:42 [inlined]
#  [8] _pycall!(::PyCall.PyObject, ::PyCall.PyObject, ::Tuple{Array{Float64,1},Array{Float64,1}}, ::Int64, ::Ptr{Nothing}) at /Users/joe/.julia/packages/PyCall/zqDXB/src/pyfncall.jl:29
#  [9] _pycall!(::PyCall.PyObject, ::PyCall.PyObject, ::Tuple{Array{Float64,1},Array{Float64,1}}, ::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /Users/joe/.julia/packages/PyCall/zqDXB/src/pyfncall.jl:11
#  [10] #pycall#116(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::typeof(PyCall.pycall), ::PyCall.PyObject, ::Type{PyCall.PyAny}, ::Array{Float64,1}, ::Vararg{Array{Float64,1},N} where N) at /Users/joe/.julia/packages/PyCall/zqDXB/src/pyfncall.jl:83
#  [11] pycall(::PyCall.PyObject, ::Type{PyCall.PyAny}, ::Array{Float64,1}, ::Vararg{Array{Float64,1},N} where N) at /Users/joe/.julia/packages/PyCall/zqDXB/src/pyfncall.jl:83
#  [12] #plot#85(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::typeof(PyPlot.plot), ::Array{Float64,1}, ::Vararg{Array{Float64,1},N} where N) at /Users/joe/.julia/packages/PyPlot/4wzW1/src/PyPlot.jl:177
#  [13] plot(::Array{Float64,1}, ::Vararg{Array{Float64,1},N} where N) at /Users/joe/.julia/packages/PyPlot/4wzW1/src/PyPlot.jl:174
#  [14] top-level scope at In[264]:7

# %%
Nc = 20
Γ = 0.5
n̄ = 10
νeff = 10.0

basis = FockBasis(Nc)
a = destroy(basis)
Ht = -νeff * dagger(a) * a
Jtt1(Γ) = [sqrt(2Γ) * a]
Jtt2(Γ) = [sqrt(2Γ) * dagger(a) * a]
Jt3 = [sqrt(2Γ * (n̄ + 1)) * a, sqrt(2Γ * n̄) * dagger(a)]
Jtt4(Γ) = [sqrt(2Γ) * (dagger(a) + a)^2]

function ρ(n̄)
    T = 1 / (log((1 / n̄) + 1))
    hf = create(basis) * destroy(basis)
    if n̄ ≡ 0
        ρ₀ = fockstate(basis, 0) ⊗ dagger(fockstate(basis, 0))
    else
        ρ₀ = thermalstate(hf, T)
    end
    return ρ₀
end
dτ = 0.001
τmax = 100
τ = [0:dτ:τmax;]
corr11 = timecorrelations.correlation(τ, ρ(0), Ht, Jtt4(Γ), dagger(a) + a,  dagger(a) + a)
corr12 = timecorrelations.correlation(τ, ρ(0), Ht, Jtt1(Γ), dagger(a) + a,  dagger(a) + a)
corr21 = timecorrelations.correlation(τ, ρ(0.5), Ht, Jtt4(Γ), dagger(a) + a,  dagger(a) + a)
corr22 = timecorrelations.correlation(τ, ρ(0.5), Ht, Jtt1(Γ), dagger(a) + a,  dagger(a) + a)
corr31 = timecorrelations.correlation(τ, ρ(3), Ht, Jtt4(Γ), dagger(a) + a,  dagger(a) + a)
corr32 = timecorrelations.correlation(τ, ρ(3), Ht, Jtt1(Γ), dagger(a) + a,  dagger(a) + a)
# corr3 = timecorrelations.correlation(τ, ρ₀, Ht, Jt3, dagger(a) + a,  dagger(a) + a);

# %%
ω, spec11 = timecorrelations.correlation2spectrum(τ, corr11; normalize_spec=false)
ω, spec12 = timecorrelations.correlation2spectrum(τ, corr12; normalize_spec=false)
ω, spec21 = timecorrelations.correlation2spectrum(τ, corr21; normalize_spec=false)
ω, spec22 = timecorrelations.correlation2spectrum(τ, corr22; normalize_spec=false)
ω, spec31 = timecorrelations.correlation2spectrum(τ, corr31; normalize_spec=false)
ω, spec32 = timecorrelations.correlation2spectrum(τ, corr32; normalize_spec=false)
# ω, spec3 = timecorrelations.correlation2spectrum(τ, corr3; normalize_spec=false);

# %%
plt.figure(figsize=(9, 3))
plt.subplot(131)
plt.plot(ω, spec11)
plt.plot(ω, spec12, ls="dashed", color="k")
plt.plot(ω, spec21)
plt.plot(ω, spec22, ls="dashed", color="k")
plt.plot(ω, spec31)
plt.plot(ω, spec32, ls="dashed", color="k")
plt.xlim(-20, 20)
plt.xlabel("freq.", fontsize=15)
plt.title(L"\mathcal{FT}\{⟨x^{\dagger}(t)x(0)⟩\}", fontsize=15)

plt.subplot(132)
plt.plot(τ, real(corr11))
plt.plot(τ, real(corr12), ls="--", color="k")
plt.plot(τ, real(corr21))
plt.plot(τ, real(corr22), ls="--", color="k")
plt.plot(τ, real(corr31))
plt.plot(τ, real(corr32), ls="--", color="k")
plt.xlim(0, 2)
plt.xlabel("time", fontsize=15)
plt.title(L"Re\{⟨x^{\dagger}(t)x(0)⟩\}", fontsize=15)

plt.subplot(133)
plt.plot(τ, imag(corr11), label="n̄=0")
plt.plot(τ, imag(corr12), ls="--", color="k")
plt.plot(τ, imag(corr21), label="n̄=0.5")
plt.plot(τ, imag(corr22), ls="--", color="k")
plt.plot(τ, imag(corr31), label="n̄=3")
plt.plot(τ, imag(corr32), label=L"D[ρ] → Γ[aρa^† - a^†aρ] + h.c.", ls="--", color="k")
plt.xlim(0, 2)
plt.xlabel("time", fontsize=15)
plt.title(L"Im\{⟨x^{\dagger}(t)x(0)⟩\}", fontsize=15)
plt.legend(bbox_to_anchor=(1, 0.5))

# plt.suptitle(L"⟨x^{\dagger}(t)x(0)⟩", fontsize=20, y=1.05)
# Out:
# PyPlot.Figure(PyObject <Figure size 900x300 with 3 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x249d30b90>

# %%
n̄ = 4
T = 1 / (log((1 / n̄) + 1))
hf = create(basis) * destroy(basis)
if n̄ ≡ 0
    ρ₀ = fockstate(basis, 0) ⊗ dagger(fockstate(basis, 0))
else
    ρ₀ = thermalstate(hf, T)
end
tspan = 0:0.1:100
tout, sol = timeevolution.master(tspan, ρ₀, Ht, Jt1);

# %%
plt.plot(tout, expect(number(basis), sol))
plt.plot(tout, expect(create(basis) + destroy(basis), sol))
plt.plot(tout, expect(im * (create(basis) - destroy(basis)), sol))
# Out:
# PyPlot.Figure(PyObject <Figure size 800x400 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x190473d90>

# %%
n̄ = 4
T = 1 / (log((1 / n̄) + 1))
hf = create(basis) * destroy(basis)
if n̄ ≡ 0
    ρ₀ = fockstate(basis, 0) ⊗ dagger(fockstate(basis, 0))
else
    ρ₀ = thermalstate(hf, T)
end
tspan = 0:1:1000
tout, sol = timeevolution.master(tspan, ρ₀, Ht, Jtt2(10));

# %%
plt.plot(tout, expect(number(basis), sol))
plt.plot(tout, expect(create(basis) + destroy(basis), sol))
plt.plot(tout, expect(im * (create(basis) - destroy(basis)), sol))
# Out:
# PyPlot.Figure(PyObject <Figure size 800x400 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x1d0d2f510>

# %%
Hs1(ν) = 2π * ν * number(basis)
Hs2(δν) = sqrt(2π * δν / 2) * number(basis)
tspan = 0:0.1:10
ψ₀ = (fockstate(basis, 1) + fockstate(basis, 3))/√2
tsol = 0
Ntraj = 250
for i in 1:Ntraj
    tout, sol = stochastic.schroedinger(tspan, ψ₀, Hs1(1), Hs2(0.1), dt=1e-5, normalize_state=true)
    tsol ≡ 0 ? tsol = dm.(sol) : tsol .+= dm.(sol)
end
sol ./= Ntraj;

# %%
plt.plot(tspan, expect(number(basis), tsol))
plt.plot(tspan, expect(create(basis) + destroy(basis), tsol))

# %%
Jm1(δν) = [sqrt(2π * δν) * number(basis)]
tout, sol = timeevolution.master(tspan, ψ₀, Hs1(1), Jm1(0.1))
plt.plot(tspan, expect(number(basis), sol))
plt.plot(tspan, expect(create(basis) + destroy(basis), sol))
