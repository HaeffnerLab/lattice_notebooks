# %%
import cmath
import numpy as np
import scipy.optimize as fitter
import matplotlib.pyplot as plt

from qutip import *
from qutip.qip.pulse import Pulse
from qutip.qip.device import Processor

# %%
import matplotlib
matplotlib.rcParams.update(
        {"font.family": "STIXGeneral",
         "xtick.labelsize": 20,
         "xtick.direction": "in",
         "xtick.major.pad": 8,
         "xtick.top": True,
         "ytick.labelsize": 20,
         "ytick.direction": "in",
         "ytick.right": True,
         "axes.labelsize": 20,
         "axes.labelpad": 10,
         "axes.grid": True
    }
)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def fitting_sin(x, A, B, ohm, phase):
    return (A * (np.sin(ohm * x + phase) + B))

'''To calculate eta (To get omega_bsb)'''
lamb = 729e-9
m = 40
u = 1.66e-27
#axial trap freq
omega_t = 2*np.pi*0.9e6
hbar = 1.05e-34
x0 = np.sqrt(hbar/(2*m*u*omega_t))
eta = (2*np.pi/lamb)*x0
print('x0 (m) = ', x0)
print('eta = ', eta)

η = 2 * np.pi * np.sqrt( ħ / (2 * ω * 6.6551079e-26)) / 729e-9; η

'''From Roos P80'''
ħ = 1           #6.62607004e-34 / (2 * np.pi)
f_ω = 2.14      #e6
delta = 6.72    #e6 #4.11523e14
omega = 10
omega_bsb = omega * np.sqrt(0+1) * η
# Out:
# x0 (m) =  1.182454458420721e-08
# eta =  0.10191468421890354
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#1 Considering the pulse for Blue sideband (To get fitted T for our pulse)
'''We can Treat 20MHz as reference'''
Times = 10
Nstates = 5
internal_ini = np.sqrt(1/2) * basis(2, 0) + np.sqrt(1/2) * basis(2, 1)
oscillation_ini = basis(Nstates, 0)
psi0_ini = tensor(internal_ini, oscillation_ini)

'''Sigma-Z, sigmaz(). Sigma plus, sigmap(). Sigma minus, sigmam()'''
a_bsb = tensor(qeye(2), destroy(Nstates))
a_bsb_dagger = tensor(qeye(2), create(Nstates))
sigmaZ_bsb = tensor(sigmaz(), qeye(Nstates))
sigmaP_bsb = tensor(sigmap(), qeye(Nstates))
sigmaM_bsb = tensor(sigmam(), qeye(Nstates))

H_0 = ħ*f_ω*2*np.pi*(a_bsb_dagger * a_bsb) + ħ*delta*0.5*2*np.pi*(sigmaZ_bsb)
H_blue = ħ*omega_bsb*2*np.pi*(a_bsb * sigmaP_bsb - a_bsb_dagger * sigmaM_bsb)*1j
H = H_blue
tg = 1
t_list = np.linspace(0, tg, 1000)
output_bsb = mesolve(H, psi0_ini, t_list, [])

down_bsb = tensor(basis(2, 0), qeye(Nstates))
up_bsb = tensor(basis(2, 1), qeye(Nstates))

state0_bsb = down_bsb * down_bsb.dag()
state1_bsb = up_bsb * up_bsb.dag()
result0_bsb = expect(state0_bsb, output_bsb.states)
result1_bsb = expect(state1_bsb, output_bsb.states)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
'''To check whether the result is reasonable'''
'''Note: this fitting is quite sensitive to initial values'''
par0 = np.array([0.25,1,10,8])
par, cov = fitter.curve_fit(fitting_sin, t_list, result0_bsb, par0)
fit_y = fitting_sin(t_list, *par)

plt.figure(figsize = (15, 10))
plt.rc('font',family='Times New Roman')
plt.plot(t_list, fit_y, 'r--', lw=2)
plt.scatter(t_list, result0_bsb, color='k', marker='o', linewidths = 0.1)
plt.title('Fitting Result', fontdict={'family' : 'Times New Roman', 'size':25})
plt.xlabel('T (unit defined optionally)', fontdict={'family' : 'Times New Roman', 'size':20})
plt.ylabel('Probability', fontdict={'family' : 'Times New Roman', 'size':20})
plt.yticks(fontproperties='Times New Roman', size=15)
plt.xticks(fontproperties='Times New Roman', size=15)
plt.legend(("Fitting Curve", "Original Data"), fontsize=20)
plt.grid()
plt.show()

'''Optimal T has been obtained'''
T = 2 * np.pi / par[2]
print(T)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0.4906051972911505

# %%
#1 Considering the pulse for Blue sideband (Using abtained T to simulate this progress)
H = H_blue
print(T)
tg = T/2
t_list = np.linspace(0, tg, 100)
output_pulse = mesolve(H, psi0_ini, t_list, [])
psi_after_bsb = output_pulse.states[-1]

'''To check whether the result is reasonable'''
result0_bsb = expect(state0_bsb, output_pulse.states)
result1_bsb = expect(state1_bsb, output_pulse.states)

plt.figure(figsize = (15, 10))
plt.rc('font',family='Times New Roman')
plt.plot(t_list,result0_bsb,marker='o',label='Down')
plt.plot(t_list,result1_bsb,marker='o',label='Up')
plt.title('Blue Sideband Pulse', fontdict={'family' : 'Times New Roman', 'size':25})
plt.xlabel('T (unit defined optionally)', fontdict={'family' : 'Times New Roman', 'size':20})
plt.ylabel('Probability', fontdict={'family' : 'Times New Roman', 'size':20})
plt.yticks(fontproperties='Times New Roman', size=15)
plt.xticks(fontproperties='Times New Roman', size=15)
plt.legend(("Down", "Up"), fontsize=20)
plt.grid()
plt.show()
print(output_pulse.states[0])
print(output_pulse.states[-1])

p_down_0 = []
p_down_1 = []
p_up_0 = []
p_up_1 = []
for i in range(len(t_list)):
    p_down_0.append(float(abs(output_pulse.states[i][0]))**2)
    p_down_1.append(float(abs(output_pulse.states[i][1]))**2)
    p_up_0.append(float(abs(output_pulse.states[i][Nstates]))**2)
    p_up_1.append(float(abs(output_pulse.states[i][Nstates+1]))**2)

plt.figure(figsize = (15, 10))
plt.rc('font',family='Times New Roman')
plt.plot(t_list,p_down_0,marker='o',label='p_down_0')
plt.plot(t_list,p_down_1,marker='o',label='p_down_1')
plt.plot(t_list,p_up_0,marker='o',label='p_up_0')
plt.plot(t_list,p_up_1,marker='o',label='p_up_1')
plt.title('Blue Sideband Pulse', fontdict={'family' : 'Times New Roman', 'size':25})
plt.xlabel('T (unit defined optionally)', fontdict={'family' : 'Times New Roman', 'size':20})
plt.ylabel('Probability', fontdict={'family' : 'Times New Roman', 'size':20})
plt.yticks(fontproperties='Times New Roman', size=15)
plt.xticks(fontproperties='Times New Roman', size=15)
plt.legend(("p_down_0", "p_down_1", 'p_up_0', 'p_up_0'), fontsize=20)
plt.grid()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0.4906051972911505
# Quantum object: dims = [[2, 5], [1, 1]], shape = (10, 1), type = ket
# Qobj data =
# [[0.70710678]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.70710678]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# Quantum object: dims = [[2, 5], [1, 1]], shape = (10, 1), type = ket
# Qobj data =
# [[ 1.37385617e-05]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 7.07120220e-01]
#  [-7.07093342e-01]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]
#  [ 0.00000000e+00]]

# %%
#2 To Simulate Ramsey Wait Time
'''To define the environment'''
dim = 8
#H_environment = qeye(dim)
a_envir = destroy(dim)
a_envir_dagger = create(dim)
H_environment = ħ*f_ω*2*np.pi*(a_envir_dagger * a_envir)
environment_ini = basis(dim, 0)
rho_after_bsb = tensor(psi_after_bsb, environment_ini)

'''To define the collapse operator'''
'''γ*nh = 2 quanta / 100 ms = 0.02'''
γ = 0.0002
nh = 100
collapse_ope = tensor(qeye(2), qeye(Nstates), (np.sqrt(γ * (nh + 1)) * destroy(dim) + np.sqrt(γ * nh) * create(dim)))

H_wait = tensor(H_0, H_environment)
t_wait = 5
t_wait_list = np.linspace(0, t_wait, 200)
output_wait = mesolve(H_wait, rho_after_bsb, t_wait_list, [collapse_ope], [])
#output_wait = mesolve(H_wait, rho_after_bsb, t_wait_list)
rho_after_wait = output_wait.states[-1]
rho_after_wait = rho_after_wait.ptrace([0, 1])

'''To check whether the result is reasonable'''
down_wait = tensor(basis(2, 0), qeye(Nstates), qeye(dim))
up_wait = tensor(basis(2, 1), qeye(Nstates), qeye(dim))
state0_wait = down_wait * down_wait.dag()
state1_wait = up_wait * up_wait.dag()
result0_wait = expect(state0_wait, output_wait.states)
result1_wait = expect(state1_wait, output_wait.states)

plt.figure(figsize = (15, 10))
plt.rc('font', family='Times New Roman')
plt.scatter(t_wait_list, result0_wait, marker='o', linewidths = 5)
plt.scatter(t_wait_list, result1_wait, marker='o', linewidths = 5)
plt.title('Ramsey Result', fontdict={'family' : 'Times New Roman', 'size':25})
plt.xlabel('T (unit defined optionally)', fontdict={'family' : 'Times New Roman', 'size':20})
plt.ylabel('Probability', fontdict={'family' : 'Times New Roman', 'size':20})
plt.yticks(fontproperties='Times New Roman', size=15)
plt.xticks(fontproperties='Times New Roman', size=15)
plt.legend(("Down", "Up"), fontsize=20)
plt.grid(True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ground_wait = tensor(qeye(2), basis(Nstates, 0), qeye(dim))
excited_wait = tensor(qeye(2), basis(Nstates, 1), qeye(dim))
leakage_wait = tensor(qeye(2), basis(Nstates, 2), qeye(dim))
State0_wait = ground_wait * ground_wait.dag()
State1_wait = excited_wait * excited_wait.dag()
State2_wait = leakage_wait * leakage_wait.dag()
Result0_wait = expect(State0_wait, output_wait.states)
Result1_wait = expect(State1_wait, output_wait.states)
Result2_wait = expect(State2_wait, output_wait.states)

plt.figure(figsize = (15, 10))
plt.rc('font', family='Times New Roman')
plt.scatter(t_wait_list, Result0_wait, marker='o', linewidths = 1)
plt.scatter(t_wait_list, Result1_wait, marker='o', linewidths = 1)
plt.scatter(t_wait_list, Result2_wait, marker='o', linewidths = 1)
plt.title('Ramsey Result', fontdict={'family' : 'Times New Roman', 'size':25})
plt.xlabel('T (unit defined optionally)', fontdict={'family' : 'Times New Roman', 'size':20})
plt.ylabel('Probability', fontdict={'family' : 'Times New Roman', 'size':20})
plt.yticks(fontproperties='Times New Roman', size=15)
plt.xticks(fontproperties='Times New Roman', size=15)
plt.legend(("ground_wait", "excited_wait", "leakage_wait"), fontsize=20)
plt.grid(True)
plt.show()

plt.figure(figsize = (15, 10))
plt.rc('font', family='Times New Roman')
plt.scatter(t_wait_list, Result0_wait, marker='o', linewidths = 1)
plt.scatter(t_wait_list, Result2_wait, marker='o', linewidths = 1)
plt.title('Ramsey Result', fontdict={'family' : 'Times New Roman', 'size':25})
plt.xlabel('T (unit defined optionally)', fontdict={'family' : 'Times New Roman', 'size':20})
plt.ylabel('Probability', fontdict={'family' : 'Times New Roman', 'size':20})
plt.yticks(fontproperties='Times New Roman', size=15)
plt.xticks(fontproperties='Times New Roman', size=15)
plt.legend(("ground_wait", "leakage_wait"), fontsize=20)
plt.grid(True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
final_state_flat = [item for sublist in output_wait.states[-1] for item in sublist]
flat_list = []
for sublist in final_state_flat:
    for item in sublist:
        flat_list.append(abs(item))

plt.figure(figsize = (15, 10))
plt.rc('font', family='Times New Roman')
plt.plot(np.arange(0, (len(flat_list)), 1), flat_list)
plt.title('Final State', fontdict={'family' : 'Times New Roman', 'size':25})
plt.xlabel('Elements', fontdict={'family' : 'Times New Roman', 'size':20})
plt.ylabel('Probability', fontdict={'family' : 'Times New Roman', 'size':20})
plt.yticks(fontproperties='Times New Roman', size=15)
plt.xticks(fontproperties='Times New Roman', size=15)
plt.legend(("Probability distribution in final state",), fontsize=20)
plt.grid(True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
p_dist_bases = []
for i in range(dim):
    opr_temp = tensor(qeye(2), qeye(Nstates), basis(dim, i))
    measure_temp = opr_temp * opr_temp.dag()
    p_dist_bases.append(expect(measure_temp, output_wait.states[-1]))

plt.figure(figsize = (15, 10))
plt.rc('font', family='Times New Roman')
plt.plot(np.arange(0, dim, 1), p_dist_bases, color='C0', marker='o', lw = 1)
plt.title('Final State', fontdict={'family' : 'Times New Roman', 'size':25})
plt.xlabel('Thermal States', fontdict={'family' : 'Times New Roman', 'size':20})
plt.ylabel('Probability', fontdict={'family' : 'Times New Roman', 'size':20})
plt.yticks(fontproperties='Times New Roman', size=15)
plt.xticks(fontproperties='Times New Roman', size=15)
plt.legend(("Probability distribution in different thermal states",), fontsize=20)
plt.grid(True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#3 & #4 Considering the pulse for Blue sideband (for after_wait_state)
H = H_blue  #[H_0, H_blue]
#T = 0.5000002981796713
tg = T/2
t_list = np.linspace(0, tg, 100)
output_bsb = mesolve(H, rho_after_wait, t_list, [])
rho_after_bsb = output_bsb.states[-1]
rho_after_bsb = rho_after_bsb.ptrace(0)
Hadamard = snot()
rho_for_measure = Hadamard * rho_after_bsb * Hadamard.dag()

result0_bsb = expect(state0_bsb, output_bsb.states)
result1_bsb = expect(state1_bsb, output_bsb.states)

plt.figure(figsize = (15, 10))
plt.rc('font',family='Times New Roman')
plt.plot(t_list,result0_bsb,marker='o',label='Down')
plt.plot(t_list,result1_bsb,marker='o',label='Up')
plt.title('Blue Sideband Pulse', fontdict={'family' : 'Times New Roman', 'size':25})
plt.xlabel('T (unit defined optionally)', fontdict={'family' : 'Times New Roman', 'size':20})
plt.ylabel('Probability', fontdict={'family' : 'Times New Roman', 'size':20})
plt.yticks(fontproperties='Times New Roman', size=15)
plt.xticks(fontproperties='Times New Roman', size=15)
plt.legend(("Down", "Up"), fontsize=20)
plt.grid(True)
plt.show()

print(rho_for_measure)

state0 = basis(2, 0) * basis(2, 0).dag()
state1 = basis(2, 1) * basis(2, 1).dag()
result0 = expect(state0, rho_for_measure)
result1 = expect(state1, rho_for_measure)
print(result0)
print(result1)

# %%
#5-1 Simulate the entire process
'''Definations'''
'''
T_bsb = T
tg = T/2
t_list_bsb = np.linspace(0, tg, 100)
γ = 0.0002
nh = 100
Nstates = 5
dim = 10
internal_ini = np.sqrt(1/2) * basis(2, 0) + np.sqrt(1/2) * basis(2, 1)
oscillation_ini = basis(Nstates, 0)
Hadamard = snot()
psi0_ini = tensor(internal_ini, oscillation_ini)
a_bsb = tensor(qeye(2), destroy(Nstates))
a_bsb_dagger = tensor(qeye(2), create(Nstates))
sigmaZ_bsb = tensor(sigmaz(), qeye(Nstates))
sigmaP_bsb = tensor(sigmap(), qeye(Nstates))
sigmaM_bsb = tensor(sigmam(), qeye(Nstates))
down_bsb = tensor(basis(2, 0), qeye(Nstates))
up_bsb = tensor(basis(2, 1), qeye(Nstates))
state0_bsb = down_bsb * down_bsb.dag()
state1_bsb = up_bsb * up_bsb.dag()
state0 = basis(2, 0) * basis(2, 0).dag()
state1 = basis(2, 1) * basis(2, 1).dag()

environment_ini = basis(dim, 0)
a_envir = destroy(dim)
a_envir_dagger = create(dim)
H_environment = 2*np.pi*(a_envir_dagger * a_envir)
H_0 = 2*np.pi*(a_bsb_dagger * a_bsb) + 0.5*2*np.pi*(sigmaZ_bsb)
H_blue = 2*np.pi*(a_bsb * sigmaP_bsb - a_bsb_dagger * sigmaM_bsb)*1j
collapse_ope = tensor(qeye(2), qeye(Nstates), (np.sqrt(γ * (nh + 1)) * destroy(dim) + np.sqrt(γ * nh) * create(dim)))
H_wait = tensor(H_0, H_environment)

T_list = []
final_down = []
final_up = []
for i in range(20):
    t_wait = 5 * i + 1
    T_list.append(t_wait)
    print(t_wait)
    #BSB
    H = [H_0, H_blue]
    output_pulse_temp = mesolve(H, psi0_ini, t_list_bsb, [])
    psi_after_bsb_temp = output_pulse_temp.states[-1]

    #Ramsey Wait Time
    rho_after_bsb_temp = tensor(psi_after_bsb_temp, environment_ini)
    t_wait_list = np.linspace(0, t_wait, 2000)
    output_wait_temp = mesolve(H_wait, rho_after_bsb_temp, t_wait_list, [collapse_ope], [])
    rho_after_wait_temp = output_wait_temp.states[-1]
    rho_after_wait_temp = rho_after_wait_temp.ptrace([0, 1])

    #BSB
    output_bsb_temp = mesolve(H, rho_after_wait_temp, t_list_bsb, [])
    rho_after_bsb_temp = output_bsb_temp.states[-1]
    rho_after_bsb_temp = rho_after_bsb_temp.ptrace(0)
    rho_for_measure_temp = Hadamard * rho_after_bsb_temp * rho_after_bsb_temp.dag() * Hadamard.dag()
    result0 = expect(state0, rho_for_measure_temp)
    result1 = expect(state1, rho_for_measure_temp)
    final_down.append(result0)
    final_up.append(result1)

'''

# %%
#5-2 Simulate the entire process
'''output_wait = mesolve(H_wait, rho_after_bsb, t_wait_list, [collapse_ope], [])'''
rhos = output_wait.states
for i in range(len(rhos)):
    rhos[i] = rhos[i].ptrace([0, 1])

T_bsb = T
tg = T/2
t_list_bsb = np.linspace(0, tg, 100)
final_down = []
final_up = []
for i in range(len(rhos)):
    H = H_blue  #[H_0, H_blue]
    output_pulse_temp = mesolve(H, rhos[i], t_list_bsb, [])
    rho_after_bsb_temp = output_pulse_temp.states[-1]
    rho_after_bsb_temp = rho_after_bsb_temp.ptrace(0)
    rho_for_measure_temp = Hadamard * rho_after_bsb_temp * Hadamard.dag()
    result0 = expect(state0, rho_for_measure_temp)
    result1 = expect(state1, rho_for_measure_temp)
    final_down.append(result0)
    final_up.append(result1)

# %%
'''plt.plot'''
plt.figure(figsize = (15, 10))
plt.rc('font',family='Times New Roman')
plt.scatter(range(len(final_down)), final_down, color='C0', marker='.')
plt.title('Ramsey Final Result', fontdict={'family' : 'Times New Roman', 'size':25})
plt.xlabel('T (unit defined optionally)', fontdict={'family' : 'Times New Roman', 'size':20})
plt.ylabel('Probability', fontdict={'family' : 'Times New Roman', 'size':20})
plt.yticks(fontproperties='Times New Roman', size=15)
plt.xticks(fontproperties='Times New Roman', size=15)
plt.legend(("Down (Ramsey Final Result)",), fontsize=20)
plt.grid(True)
plt.show()

# %%
a_dagger = tensor(create(2), qeye(Nstates), qeye(dim))
a = tensor(destroy(2), qeye(Nstates), qeye(dim))
tlist = np.linspace(0, 50, 1000)
psi_after_bsb_envir = tensor(psi_after_bsb, basis(dim, 0))
result = mesolve(H_wait, psi_after_bsb_envir, tlist, [collapse_ope], [])
'''[np.sqrt(0.05) * sigmax()], [sigmaz(), sigmay()]'''

ground = basis(2,0)
excited = basis(2,1)
state0 = ground * ground.dag()
state1 = excited * excited.dag()
psis = result.states

# %%
T_bsb = T
tg = T/2
t_list_bsb = np.linspace(0, tg, 100)
final_0 = []
final_1 = []
for i in range(len(psis)):
    H = tensor(H_blue, qeye(dim))
    output_pulse_temp = mesolve(H, psis[i], tlist, [])
    psi_after_bsb_temp = output_pulse_temp.states[-1]
    rho_temp = psi_after_bsb_temp*psi_after_bsb_temp.dag()
    rho_temp = rho_temp.ptrace(0)
    rho_for_measure_temp = Hadamard * rho_temp * Hadamard.dag()
    result0 = expect(state0, rho_for_measure_temp)
    result1 = expect(state1, rho_for_measure_temp)
    final_0.append(result0)
    final_1.append(result1)

'''plt.plot'''
plt.figure(figsize = (15, 10))
plt.rc('font',family='Times New Roman')
plt.scatter(range(len(final_0)), final_0, color='C0', marker='.')
plt.title('Ramsey Final Result', fontdict={'family' : 'Times New Roman', 'size':25})
plt.xlabel('T (unit defined optionally)', fontdict={'family' : 'Times New Roman', 'size':20})
plt.ylabel('Probability', fontdict={'family' : 'Times New Roman', 'size':20})
plt.yticks(fontproperties='Times New Roman', size=15)
plt.xticks(fontproperties='Times New Roman', size=15)
plt.legend(("final_0",), fontsize=20)
plt.grid(True)
plt.show()

# %%
def calc_phase_check(x):
    x = np.array(x)
    xerr = np.sqrt(x * (1 - x) / 1000)
    #result
    B = (x[0] + x[2]) / 2
    N = x[1] - B
    D = x[0] - B
    ϕ = np.arctan2(N, D)
    A = np.sqrt(((x[2] - x[0])/2)**2 + ((2 * x[1] - x[0] - x[2])/2)**2)
    
    #error
    temp_a = xerr[2]**2 * (x[0] - x[1])**2 + xerr[1]**2 * (x[0] - x[2])**2 + xerr[0]**2 * (x[1] - x[2])**2
    temp_b = (x[0]**2 - 2 * x[0] * x[1] + 2 * x[1]**2 - 2 * x[1] *x[2] + x[2]**2)**2
    error_ϕ = np.sqrt(temp_a / temp_b)
    error_B = np.sqrt((1/4) * xerr[0]**2 + (1/4) * xerr[2]**2)
    temp_a_A = xerr[0]**2 * (x[0] - x[1])**2 + xerr[2]**2 * (x[1] - x[2])**2 + xerr[1]**2 * (x[0] - 2*x[1] + x[2])**2
    temp_b_A = x[0]**2 - 2 * x[0] * x[1] + 2 * x[1]**2 - 2 * x[1] * x[2] + x[2]**2
    error_A = np.sqrt(temp_a_A / temp_b_A)
    return ϕ, error_ϕ, A, error_A, B, error_B

# %%
from scipy.signal import find_peaks
final_0 = np.array(final_0)
max = find_peaks(final_0)

# %%
def d_phase(A, B, phase):
    coe = 1 / (10 * np.sqrt(2))
    result_temp = np.sqrt((-1/A**2) * (A**2*np.cos(phase)**4) + (B - 1)*B*np.sin(phase)**2 + np.cos(phase)**2*(3*(B-1)*B+4*A*(2*B-1)*np.sin(phase)+3*A**2*np.sin(phase)**2))
    return result_temp * coe
